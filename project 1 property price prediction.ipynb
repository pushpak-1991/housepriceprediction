# %%
import pandas as pd

# %%
import numpy as np

# %%
# !pip install sklearn#import ML library
# Out:
# ERROR: Invalid requirement: 'sklearn#import'

# %%
csv_import=pd.read_csv("HousePrices.csv")# import csv file from the file directory

# %%
csv_import
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
csv_import.isnull().sum()#check for th null values
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
a=csv_import.columns[csv_import.isnull().any()]
csv_import[a].isnull().sum()
# to view all the null values in the data
# Out:
# LotFrontage      320
# Alley           1944
# MasVnrType        14
# MasVnrArea        14
# BsmtQual          59
# BsmtCond          59
# BsmtExposure      61
# BsmtFinType1      59
# BsmtFinType2      60
# Electrical         1
# FireplaceQu      988
# GarageType       113
# GarageYrBlt      113
# GarageFinish     113
# GarageQual       113
# GarageCond       113
# PoolQC          2065
# Fence           1669
# MiscFeature     1993
# dtype: int64

# %%
csv_import.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
#fill up the null values by the mean

# %%
csv_import["LotFrontage"].fillna((csv_import["LotFrontage"].mean()),inplace=True)
csv_import
#LotFrontage null values filled with mean
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL    65.000000     8450      Pave   NaN
# 1       2          20         RL    80.000000     9600      Pave   NaN
# 2       3          60         RL    68.000000    11250      Pave   NaN
# 3       4          70         RL    60.000000     9550      Pave   NaN
# 4       5          60         RL    84.000000    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL    72.056475     8755      Pave   NaN
# 2069  943          90         RL    63.000000     7711      Pave   NaN
# 2070  944          90         RL   313.000000    25000      Pave   NaN
# 2071  945          20         RL    52.000000    14375      Pave   NaN
# 2072  946          50         RM    98.000000     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
csv_import["MasVnrArea"].fillna((csv_import["MasVnrArea"].mean()),inplace=True)
csv_import
#MasVnrArea filled null values with mean
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL    65.000000     8450      Pave   NaN
# 1       2          20         RL    80.000000     9600      Pave   NaN
# 2       3          60         RL    68.000000    11250      Pave   NaN
# 3       4          70         RL    60.000000     9550      Pave   NaN
# 4       5          60         RL    84.000000    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL    72.056475     8755      Pave   NaN
# 2069  943          90         RL    63.000000     7711      Pave   NaN
# 2070  944          90         RL   313.000000    25000      Pave   NaN
# 2071  945          20         RL    52.000000    14375      Pave   NaN
# 2072  946          50         RM    98.000000     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
property_data=pd.DataFrame(csv_import)#convert the csv into DF

# %%
property_data
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL    65.000000     8450      Pave   NaN
# 1       2          20         RL    80.000000     9600      Pave   NaN
# 2       3          60         RL    68.000000    11250      Pave   NaN
# 3       4          70         RL    60.000000     9550      Pave   NaN
# 4       5          60         RL    84.000000    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL    72.056475     8755      Pave   NaN
# 2069  943          90         RL    63.000000     7711      Pave   NaN
# 2070  944          90         RL   313.000000    25000      Pave   NaN
# 2071  945          20         RL    52.000000    14375      Pave   NaN
# 2072  946          50         RM    98.000000     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
x=property_data[['LotArea','YearBuilt','OverallQual','OverallCond','BedroomAbvGr','KitchenAbvGr','LowQualFinSF','BsmtFinSF2','GarageCars','GarageArea','YrSold','PoolArea','FullBath','TotalBsmtSF','GrLivArea','ScreenPorch','HalfBath','BsmtFullBath','2ndFlrSF']]#independent

# %%
y=property_data['Property_Sale_Price']#dependent(output)

# %%
print(x)
# Out:
#       LotArea  YearBuilt  OverallQual  OverallCond  BedroomAbvGr  \
# 0        8450       2003            7            5             3
# 1        9600       1976            6            8             3
# 2       11250       2001            7            5             3
# 3        9550       1915            7            5             3
# 4       14260       2000            8            5             4
# ...       ...        ...          ...          ...           ...
# 2068     8755       1936            8            4             3
# 2069     7711       1936            6            9             4
# 2070    25000       1983            4            6             4
# 2071    14375       1958            9            6             3
# 2072     8820       1890            9            9             2
#
#       KitchenAbvGr  LowQualFinSF  BsmtFinSF2  GarageCars  GarageArea  YrSold  \
# 0                1             0           0           2         548    2008
# ...

# %%
print(y)
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 2068    214000
# 2069    150000
# 2070    143000
# 2071    137500
# 2072    124900
# Name: Property_Sale_Price, Length: 2073, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.7682307306892314

# %%
model.predict([[9874,1986,9,10,4,2,110,310,1,387,2000,0,2,999,1374,100,0,2,1000]])
# Out:
# array([148117.642739])

# %%
from sklearn.model_selection import train_test_split#import

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg_mod=LinearRegression()

# %%
lin_reg_mod.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lin_reg_mod.predict(x_test)

# %%
pred
# Out:
# array([ 96318.96665059, 163600.39488778, 242981.34944226, 177266.80620281,
#        103825.94594604, 178951.78908928, 106011.601313  , 220716.94351812,
#        238514.47169032, 149845.81403285, 118720.96281732, 247694.2653479 ,
#        310356.89267245, 180427.14232648, 225653.83677286, 258606.36282905,
#        129660.98523861, 190954.50196215, 112930.31607639,  70007.90291278,
#        211234.81118077, 200827.09240255, 129352.06825735, 195548.32606861,
#        219127.92398765, 216869.98537777, 234848.6786444 ,  98388.98621064,
#        245202.54916301, 149394.29853305, 273004.21711094, 205109.38317207,
#        132412.0723919 , 268468.42930277, 158827.38627318, 128438.35964009,
#        112214.75212179, 183135.89481149, 134289.66039284, 104225.43888874,
#        216017.62546788, 152798.17115823, 139720.62740658,  62337.86559314,
#        203914.01834649, 204461.06485121,  95551.92113496, 159281.83694928,
# ...

# %%
import numpy as np
from sklearn import metrics
test_set_r2=metrics.r2_score(y_test,pred)

# %%
print(test_set_r2)
# Out:
# 0.7726026078828557

# %%
lin_reg_mod.predict([[9874,1986,9,10,4,2,110,310,1,387,2000,0,2,999,1374,100,0,2,1000]])
# Out:
# array([148462.70870764])

# %%
import seaborn as sb

# %%
model.coef_
# Out:
# array([ 2.60329399e-01,  2.84942373e+02,  4.29769811e+03,  3.57182228e+03,
#        -9.70006934e+03, -4.48668529e+04, -4.86727397e+01, -1.96543734e+01,
#         1.76202527e+04,  6.18749559e+00, -3.62574602e+02, -1.44707263e+02,
#         1.42232376e+04,  3.30689396e+01,  7.92933955e+01,  5.31769016e+01,
#         7.04436570e+03,  1.34500131e+04, -7.95257673e+00])
